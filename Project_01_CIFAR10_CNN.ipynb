# %% [markdown]
# <a href="https://colab.research.google.com/github/gifeonu-PGee/enog-server/blob/main/Project_01_CIFAR10_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
x_train.shape

# %%
print(x_train[0].shape)
plt.imshow(x_train[0])
plt.show()

# %%
print(y_train[0])

# %%
x_train = x_train / 255.0
x_test = x_test /255.0

# %% [markdown]
# what i just did here is called normalization to help the optimizer learn faster and smoothly.we normalize images by dividing pixel values by 255 so that all pixel valves fall between 0 and 1.

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([

    tf.keras.layers.Conv2D(
        filters=32,
        kernel_size=(3,3),
        activation='relu',
        input_shape=(32,32,3)
    ),

    tf.keras.layers.MaxPooling2D(pool_size=(2,2)),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(64, activation='relu'),

    tf.keras.layers.Dense(10, activation='softmax')

])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=5,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 30s 44ms/step - accuracy: 0.1297 - loss: 4.4800 - val_accuracy: 0.1713 - val_loss: 2.2222
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 38s 41ms/step - accuracy: 0.2175 - loss: 2.0931 - val_accuracy: 0.2415 - val_loss: 1.9743
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 27s 42ms/step - accuracy: 0.2658 - loss: 1.8832 - val_accuracy: 0.2726 - val_loss: 1.8571
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 39s 40ms/step - accuracy: 0.3056 - loss: 1.7739 - val_accuracy: 0.3189 - val_loss: 1.7506
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 42ms/step - accuracy: 0.3507 - loss: 1.6702 - val_accuracy: 0.3556 - val_loss: 1.6920
